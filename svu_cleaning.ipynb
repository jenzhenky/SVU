# %% [markdown]
# ## Convert Raw SVU Data to a Clean Dataframe

# %% [markdown]
# Code to generate a dataframe with data from every episode of SVU.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import matplotlib as plt
# %matplotlib inline

import re

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Import raw data

# %%
df_episode = pd.read_csv(r'C:\Users\Jenny\svu\episode.csv', parse_dates=['date_published'])
df_cast = pd.read_csv(r'C:\Users\Jenny\svu\cast.csv')
df_episode.head(1)
# Out:
#   date_published     episode episode_name rating_count  rating_value     season
# 0 1999-09-20       Episode 1  Payback      511          8.4           Season 1

# %%
del df_cast['cast_ranking']
df_cast.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      actor                                                                                                                                                                                                                                                                                                                                                                                                                                                                          character episode_name
# 0  Christopher Meloni,Mariska Hargitay,Richard Belzer,Dann Florek,Gordana Rashovich,Dean Winters,Michelle Hurd,Isabel Gillies,Elizabeth Ashley,Ned Eisenberg,Tina Benko,Ronald Guttman,Mark Zimmerman,Angie Harmon,Mili Avital,Leslie Hendrix,P.J. Brown,Ramsey Faragallah,Rebecca Creskoff,Angela Bullock,Mark Nelson,Jeremy Bergman,Matt Skollar,Irma St. Paule,Sevanne Kassarjian,Daniel Bess,Judy Del Giudice,Bill Driscoll,Vivian Nesbitt,Chris Orbach,Jesse Jesus Salazar,Frank Anello,Rohan Quine,Steven Zirnkilton  Elliot Stabler,Olivia Benson,John Munch,Donald Cragen,Anya Rugova,Brian Cassidy,Monique Jeffries,Kathy Stabler,Serena Benson,Jerry Kleinert,Mrs. Panacek,Gallery Owner,Mr. Dupree,Abbie Carmichael,Marta Stevens,Dr. Elizabeth Rodgers,Bremmer,Taxi Driver,Waitress,Prosecutor,Robert Stevens,Nicholas Stevens,Victor Spicer,Aunt Jashari,Ileana Jashari,Policeman,Judge,Mr. Kloster,Farley,Detective Ken Briscoe,Victim,NYPD Officer,Gallery Owner's assistant,Opening Announcer  Payback

# %% [markdown]
# ### Create and clean lists for actor and character

# %%
# For character: split on commas that aren't followed by a space, remove slash (if not accompanied with text) and the element after it, remove voice roles
# For actor: remove actors whose roles are not listed
df_cast['actor'] = [re.sub(r'Cheryl Alexander,|Terri Douglas,|Valerie Geffner,|Henry Strozier,|Christofer de Oni,', '', item) for item in df_cast['actor']]
df_cast['actor'] = df_cast['actor'].apply(lambda x: x.split(','))

df_cast['character'] = [re.sub(r',/,\w*|,Additional \w*|,Jon Freeman|\s\s+', ' ', item) for item in df_cast['character']]
df_cast['character'] = [re.split(r',(?!\s)', item) for item in df_cast['character']]
df_cast.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         actor  \
# 0  [Christopher Meloni, Mariska Hargitay, Richard Belzer, Dann Florek, Gordana Rashovich, Dean Winters, Michelle Hurd, Isabel Gillies, Elizabeth Ashley, Ned Eisenberg, Tina Benko, Ronald Guttman, Mark Zimmerman, Angie Harmon, Mili Avital, Leslie Hendrix, P.J. Brown, Ramsey Faragallah, Rebecca Creskoff, Angela Bullock, Mark Nelson, Jeremy Bergman, Matt Skollar, Irma St. Paule, Sevanne Kassarjian, Daniel Bess, Judy Del Giudice, Bill Driscoll, Vivian Nesbitt, Chris Orbach, Jesse Jesus Salazar, Frank Anello, Rohan Quine, Steven Zirnkilton]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               character episode_name
# 0  [Elliot Stabler, Olivia Benson, John Munch, Donald Cragen, Anya Rugova, Brian Cassidy, Monique Jeffries, Kathy Stabler, Serena Benson, Jerry Kleinert, Mrs. Panacek, Gallery Owner, Mr. Dupree, Abbie Carmichael, Marta Stevens, Dr. Elizabeth Rodgers, Bremmer, Taxi Driver, Waitress, Prosecutor, Robert Stevens, Nicholas Stevens, Victor Spicer, Aunt Jashari, Ileana Jashari, Policeman, Judge, Mr. Kloster, Farley, Detective Ken Briscoe, Victim, NYPD Officer, Gallery Owner's assistant, Opening Announcer]  Payback

# %%
# Create a list of characters to see if it needs to be cleaned for consistency
list_character = list(set([item for sublist in list(df_cast['character']) for item in sublist]))

# Remove extra quotation marks, remove leading whitespaces, remove any text in parenthesis (following a whitespace)
list_character = list(set(x.replace('"','').lstrip() for x in list_character))
list_character.sort()
list_character

# Apply the changes above to df_cast['character']
df_cast['character'] = [[item.replace('"','').lstrip() for item in x] for x in df_cast['character']]
df_cast['character'].head(1)
# Out:
# 0    [Elliot Stabler, Olivia Benson, John Munch, Donald Cragen, Anya Rugova, Brian Cassidy, Monique Jeffries, Kathy Stabler, Serena Benson, Jerry Kleinert, Mrs. Panacek, Gallery Owner, Mr. Dupree, Abbie Carmichael, Marta Stevens, Dr. Elizabeth Rodgers, Bremmer, Taxi Driver, Waitress, Prosecutor, Robert Stevens, Nicholas Stevens, Victor Spicer, Aunt Jashari, Ileana Jashari, Policeman, Judge, Mr. Kloster, Farley, Detective Ken Briscoe, Victim, NYPD Officer, Gallery Owner's assistant, Opening Announcer]
# Name: character, dtype: object

# %%
# Create another list of characters to check if it is cleaned
list_character_cleaned = list(set([item for sublist in list(df_cast['character']) for item in sublist]))
list_character_cleaned.sort()
list_character_cleaned
# Out:
# ["'Selfie' Wife",
#  '70s Dancer',
#  '911 Operator',
#  'A.D. Doyle',
#  'A.D. Tony',
#  'A.D.A Fritz',
#  'A.D.A.',
#  'A.D.A. Bartell',
#  'A.D.A. Bettina Amador',
#  'A.D.A. Brinkman',
#  'A.D.A. David Elias',
#  'A.D.A. David Goreman',
#  'A.D.A. Derek Strauss',
#  'A.D.A. Erica Alden',
#  'A.D.A. Fahey',
#  'A.D.A. Fritz',
#  'A.D.A. Garrett Gillespie',
#  'A.D.A. Gillian Hardwicke',
#  'A.D.A. Gina Masconi',
#  'A.D.A. Harbin',
#  'A.D.A. Jo Marlowe',
#  'A.D.A. Kathleen Eastman',
#  'A.D.A. Kendra Gill',
#  "A.D.A. Kenneth O'Dwyer",
#  'A.D.A. Kristen Torres',
#  'A.D.A. Marnie Lathrop',
#  'A.D.A. Mikka Von',
#  'A.D.A. Pippa Cox',
#  'A.D.A. Rose Caliay',
#  'A.D.A. Sherri West',
#  'A.J. Dunne',
#  'A.J. Martin',
#  'A.J. Martin, Jr.',
#  'A.O.C. Productions Tech',
#  'ACS Caseworker',
#  'ACS Social Worker',
#  'ACS Supervisor',
#  'ASP Teen',
#  'ATF Agent',
#  'ATF Agent Gus Stone',
#  'ATF Supervisor',
#  'AUSA Ben Daltrey',
#  'AUSA Marion Springer',
#  'Aakif Ahmadi',
#  'Aaron Gandry',
#  'Aaron Householder',
#  'Aaron Winters',
#  'Abbie Carmichael',
#  'Abby',
#  'Abby Clarke',
#  'Abby Mannion',
#  'Abby Stans',
#  'Abby Stewart',
#  'Abraham  Hoff',
#  'Accident Victim',
#  'Accomplice Security Guard',
#  'Accordionist at Party',
#  'Activist',
#  'Adam',
#  'Adam Benitez',
#  'Adam Blake',
#  'Adam Brubeck',
#  'Adam Burke',
#  'Adam Cain',
#  'Adam Church',
#  'Adam Clayton Powell',
#  'Adam Cordell',
#  'Adam Forbes',
#  'Adam Grafton',
#  'Adam Halder',
#  'Adam Nesbit',
#  'Adam Porter',
#  'Adam Schiff',
#  'Adam Trembley',
#  'Adam Turner',
#  'Adams',
#  'Addict',
#  'Additional',
#  'Adilay Jones',
#  'Adisa',
#  'Admiral Vincent Albers',
#  'Admissions Nurse',
#  'Admitting Nurse',
#  'Adoption Agency Caseworker',
#  'Adriana March',
#  'Adrianna Vidal',
#  'Adult Film Director',
#  'Advocate',
#  'African Child',
#  'Agent #1',
#  'Agent Brianna Kalke',
#  'Agent Bruce Bigelow',
#  'Agent Doherty',
#  'Agent Hellerman',
#  'Agent Lockwood',
#  'Agent McCloskey',
#  'Agent Suarez',
#  'Agent Tim Harriman',
#  'Agent Tom Cole',
#  'Aggressive #1',
#  'Agnes Linsky',
#  'Agnes Rosen',
#  'Ahmal',
#  'Ahmet Elbisi',
#  'Aidan Connor',
#  'Aide',
#  'Aide #1',
#  'Aimee Slocum',
#  'Air Marshall',
#  'Air Traffic Control Employee',
#  'Air Traffic Supervisor',
#  'Airline Passenger',
#  'Airline Pilot',
#  'Airplane Passenger',
#  'Airport Passenger',
#  'Airport passenger',
#  'Al',
#  'Al Baker',
#  'Al Rivera',
#  'Al Shipley',
#  'Alan',
#  'Alan Anthony Winchell',
#  'Alan Buckley',
#  'Alan Hubert',
#  'Alan Messinger',
#  'Alan Munn',
#  'Alan Richter',
#  'Alan Thorpe',
#  'Alana Reed',
#  'Alanis Grey',
#  'Albert Beck',
#  'Albert Romano',
#  'Alberto Seraphine',
#  'Alden Kessler',
#  'Aldo',
#  'Alec Bernardi',
#  'Alec Harris',
#  'Alec Peters',
#  'Alec Vale',
#  'Alejandro Pavel',
#  'Alessandra Bay',
#  'Alex Parven',
#  'Alex Ryan',
#  'Alex Strizkopf',
#  'Alex Tapper',
#  'Alexa',
#  'Alexa Pierson',
#  'Alexander Gammon',
#  'Alexandra Cabot',
#  'Alexandra Eames',
#  'Alexandra Handley',
#  'Alexei Belyakov',
#  'Alexis Sutton',
#  'Alfonso',
#  'Alfonso Corrales',
#  'Alfred',
#  'Ali',
#  'Alice Gray',
#  'Alice McCain',
#  'Alice Parker',
#  'Alicia Brown',
#  'Alicia Flock',
#  'Alicia Hahn',
#  'Alicia Harding',
#  'Alicia Morley',
#  'Alicia Sandow',
#  'Alik',
#  'Alisa Davies',
#  'Alison Luhan',
#  'Allan Shaye',
#  'Allen Clyde',
#  'Allen Cooper',
#  'Allen Wheaten',
#  'Allie Martell',
#  'Allison',
#  'Allison Avery',
#  'Allison Buckley',
#  'Allison Burns',
#  'Allison Downey',
#  'Allison LoGreco',
#  'Allison Nerrit',
#  'Ally',
#  'Ally Abbott',
#  'Alma',
#  'Alma Cordoza',
#  'Alma Hernandez',
#  'Almani Bothame',
#  'Alminia Aguilar',
#  'Alonso Hearne',
#  'Alt-Right Dude',
#  'Alva Tate',
#  'Alvin Dutch',
#  'Alvin Gilbert',
#  'Alvin Maddox',
#  'Alyson',
#  'Alyssa',
#  'Amal Qinawi',
#  'Amanda',
#  'Amanda Curry',
#  'Amanda Durning',
#  'Amanda Rollins',
#  'Amber',
#  'Amber Samonsky',
#  'Amelia Chase',
#  'Amelia Cole',
#  "Amelia's Assistant",
#  'Amina Asante',
#  'Amy',
#  'Amy Bergen',
#  'Amy Carr',
#  'Amy Doe',
#  'Amy Prescott',
#  'Amy Tanner',
#  'Amy Taylor',
#  'Amy Wagner',
#  'Ana Kapic',
#  'Ana Rajic',
#  'Andre',
#  "Andre 'Hackapulco' Johnson",
#  'Andre Bushido',
#  'Andre Lasnik',
#  'Andrea Brown',
#  'Andrea Forbes',
#  'Andrea Kent',
#  'Andrea Mason',
#  'Andrea Patwin',
#  'Andreas',
#  'Andrew',
#  'Andrew Drake',
#  'Andrew Garrick',
#  'Andrew Green',
#  'Andrew Harlin',
#  'Andrew Hingham',
#  'Andrew Kenworthy',
#  'Andrew Lennox',
#  'Andrew Pennington',
#  'Andrew Raines',
#  "Andy 'The Monster' McPherson",
#  'Andy Abbott',
#  'Andy Becker',
#  'Andy Chen',
#  'Andy Copeland',
#  'Andy Lema',
#  'Andy McCollum',
#  'Andy Penza',
#  'Andy Rayburn',
#  'Andy Sherman',
#  'Andy Wall',
#  'Angel',
#  'Angel Perez',
#  'Angel Rivera',
#  "Angel's Owner",
#  'Angela',
#  'Angela Agnelli',
#  'Angela Bowden',
#  'Angela Brooks',
#  'Angela Dupree',
#  'Angela Farrell',
#  'Angela Franklin',
#  'Angela Garcia',
#  'Angela Kerns',
#  'Angela Myers',
#  'Angela Ocurro',
#  'Angela Riva',
#  'Angela Torres / Sho Ling-Fu',
#  'Angelica Rodriguez',
#  'Angelina Lupino',
#  'Angie',
#  'Angie Landricks',
#  'Angry Dad',
#  'Angry Father',
#  'Angry Woman',
#  'Angus Rochester',
#  'Aniah Butters',
#  'Animal Control Agent',
#  'Ann',
#  'Ann Brice',
#  'Ann Brown',
#  'Ann Curry',
#  'Ann Davenport',
#  'Ann Jackson',
#  'Ann Ostilow',
#  'Anna',
#  'Anna Bleers / Natalie Bleers',
#  'Anna Faust',
#  'Anna Gable',
#  'Anna Pretard',
#  'Anna Sadler',
#  'Anna Tejada',
#  'Annabel Hayes',
#  'Annabelle Avery',
#  'Annabelle Paoletti',
#  'Annabelle Paz',
#  'Anne Barnes',
#  'Anne Bentley',
#  'Anne Briggs',
#  'Anne Gillette',
#  'Anne Howell',
#  'Anne McGovern',
#  'Anne Speer',
#  'Annette Cole',
#  'Annette Fleming',
#  'Annette Fox',
#  'Annie',
#  'Annie Colon',
#  'Annie Lin',
#  'Annie Meyers',
#  'Annie Munson',
#  'Annie Tassler',
#  'Annika Bergeron',
#  'Announcer',
#  'Antawn',
#  'Anthony',
#  'Anthony Barone',
#  'Anthony Maxwell',
#  'Anthony Myers',
#  'Anthony Nomaks',
#  'Anthony Parker',
#  'Anthony Rossi',
#  'Anthony Tyrell Jones',
#  'Anthony the Bookie',
#  'Antifa Protester #1',
#  'Antifa Protester #2',
#  'Antoine',
#  'Anton Krasnikov',
#  "Anton Krasnikov's fan",
#  'Anton Nadari',
#  'Anton Petrov',
#  'Anton Thibodeaux',
#  'Antonio Dawson',
#  'Antonio Montoya',
#  'Anu Nayyar',
#  'Anya Rugova',
#  'Apartment Mom',
#  'April',
#  "April 'Ma' Hendricks",
#  'April Silva',
#  'April Troost',
#  'Apt. Manager',
#  'Arabic Woman',
#  'Archive Clerk',
#  'Archivist',
#  'Ariana Kane',
#  'Arianna',
#  'Ariel Baskins',
#  'Ariel Randolph',
#  'Ariel Thornhill',
#  'Arlene Heller',
#  'Arlene Simes',
#  'Armando Padilla',
#  'Armin Sidran',
#  'Armstrong',
#  "Army Pvt. William 'Billy' Shaughnessy",
#  'Army Recruiter',
#  'Army Staff Sgt. Tyler Jones',
#  'Arnie',
#  'Arnold Savatsky',
#  'Arraignment Clerk',
#  'Arraignment Judge',
#  'Arraignment Judge Wende Kramer',
#  'Art Student',
#  'Art Teacher',
#  "Arthur 'Artie' Blessard",
#  'Arthur Branch',
#  'Arthur Campbell',
#  'Arthur Esterman',
#  'Arthur Felton',
#  'Arthur Pruitt',
#  'Artie Kabzinski',
#  'Arturo Rivera',
#  'Asante Odufemi',
#  'Ash',
#  'Ashanti',
#  'Ashlee Walker',
#  'Ashley',
#  'Ashley Austin Black',
#  'Ashley B.',
#  'Ashley Harper',
#  'Ashley Kalreiss',
#  'Ashley Miller',
#  'Ashley Riggs',
#  'Ashley S.',
#  'Ashley Tyler',
#  'Ashtonja Abreu',
#  'Asian Girl',
#  'Asian Woman',
#  'Assemblyman Eric Molina',
#  'Assistant',
#  'Assistant D.A.',
#  'Assistant District Attorney',
#  'Assistant M.E.',
#  'Assistant M.E. Cardillo',
#  'Assistant M.E. Fielding',
#  'Assistant Medical Director Vivanne Hendrix',
#  'Assistant Medical Examiner',
#  'Assistant U.S. Attorney Christine Danielson',
#  'Asst. M.E. Karlan',
#  'Asst. US Attorney Claudia Williams',
#  'Asst. Warden McFarland',
#  'Astonished Accountant',
#  'Astrid',
#  'Atkins',
#  'Atlanta Detective',
#  'Attendant',
#  'Attendee',
#  'Attending Physician',
#  'Attorney',
#  'Attorney Alan Schwartz',
#  'Attorney Crane',
#  'Attorney Egan',
#  'Attorney General',
#  'Attorney Harris',
#  'Attorney Janet Delgado',
#  'Attorney Katz',
#  'Attorney Lynne Riff',
#  'Attorney Mitch Jackson',
#  'Attorney Owens',
#  'Attorney Regal',
#  'Attorney Richard Bannon',
#  'Attorney Ryan Egan',
#  'Attorney Schaefer',
#  'Attorney Sean Kramer',
#  'Attorney Shamal',
#  'Attorney Shore',
#  'Attorney Simone Bryce',
#  'Attorney Stern',
#  'Attorney Sullivan',
#  'Attorney Terence Moore',
#  'Attorney Van Allen',
#  'Attorney Varma',
#  'Attorney Walsh',
#  'Attorney Wilkerson',
#  'Attorney Wilmington',
#  'Atty. Harold Timmons',
#  'Atty. Sunil Varma',
#  'Aubrey Elding',
#  'Aubrey Trisler',
#  'Audrey Jackson',
#  'Audrey Thompson',
#  'Audrey Truffaut',
#  'Audrina',
#  'Audrina Sanchez',
#  'Aunt Jashari',
#  'Aunt Mary',
#  'Ava',
#  'Ava Parulis / Irina Parulis',
#  'Avery Capshaw',
#  'Avery Hemmings',
#  'Avery Jordan',
#  'Avery Parker',
#  'Avery Shaw',
#  'Avi Zelinsky',
#  'Aziza Amir',
#  'BJ',
#  'BJ Cameron',
#  'Babs Duffy',
#  'Background',
#  'Bad Ass / Javier',
#  'Bailiff',
#  'Baliff',
#  'Ballistics Tech',
#  'Balloon Vendor',
#  'Ballroom Party Guest',
#  'Bambi',
#  'Band Member',
#  'Bank Manager',
#  'Bank Teller',
#  'Banker',
#  'Bar Attendee',
#  'Bar Patron',
#  'Barbara Collins',
#  'Barbara Gilbert',
#  'Barclay Pallister',
#  'Barlow',
#  'Barry',
#  'Barry Carlisle',
#  'Barry Cole',
#  'Barry Fordes',
#  'Barry Moredock',
#  'Barry Querns',
#  'Barry Rhinehart',
#  'Bart',
#  'Bart Ganzel',
#  'Bart Levin',
#  'Bartender',
#  'Bartender Bill',
#  'Bartender Joe',
#  'Bartender Molly',
#  'Baseball Player',
#  'Basketball Arena Timekeeper',
#  'Basketball Player',
#  'Basketball Player #1',
#  'Basketball Player #2',
#  'Basketball Wife',
#  "Bates's Attorney",
#  'Bathroom Drug User',
#  'Bayard Ellis',
#  'Beatrice',
#  'Beatriz Amarante',
#  'Beau Helm',
#  'Beau Miller',
#  'Becca',
#  'Becca Rice',
#  'Becky Sorenson',
#  'Becky Underwood',
#  'Belinda',
#  'Belinda Holt',
#  'Bella',
#  'Bella Carisi',
#  'Bella Zane',
#  'Belton Merrell',
#  'Ben',
#  'Ben Campion',
#  'Ben Cohen',
#  'Ben Hadley Jr.',
#  'Ben Hicks',
#  'Ben McWilliams',
#  'Ben Moreland',
#  'Ben Nicholson',
#  'Ben Pawler',
#  'Ben Suarato',
#  "Ben Weeman's Lawyer",
#  'Benito Escobar',
#  'Benjamin Tucker',
#  'Benjy Dowe',
#  'Bennet',
#  'Benno Gilbert',
#  'Benny',
#  'Benny Edgar Ralsay',
#  'Berko Barré',
#  'Berman',
#  'Bernadette',
#  'Bernardo',
#  'Bernie',
#  'Bernie Stabler',
#  'Bernie Thorkle',
#  'Bert',
#  'Bert Ferrara',
#  'Bert Swanson',
#  'Bess Sherman',
#  'Beth',
#  'Beth Anne Rollins',
#  'Beth Burns',
#  'Beth Butler',
#  'Beth Fischer',
#  'Beth Myers',
#  'Beth Rand',
#  'Beth Rasmussen',
#  'Beth Stegman',
#  'Bethany Jennings',
#  'Bethany Taylor',
#  'Bethenny',
#  'Betty',
#  'Betty Jean',
#  'Beverly Neal',
#  'Beverly Parsons',
#  'Bianca',
#  "Bianca's Father",
#  "Bianca's Mother",
#  'Bibi',
#  'Bicycle Man',
#  'Big Jerry',
#  'Bike Cop',
#  'Bike Messenger',
#  'Bill',
#  'Bill Dixon',
#  'Bill Garnet',
#  'Bill Griswold',
#  'Bill Harris',
#  'Bill Jensen',
#  'Bill Lawrence',
#  'Bill Sullivan',
#  'Bill Tattenger',
#  'Bill Turbit',
#  'Billie Lou Hatfield',
#  'Billy',
#  'Billy Baker',
#  'Billy Skags',
#  'Billy The Gravedigger',
#  'Billy Tripley',
#  'Billy Turner',
#  'Biological Mother',
#  'Birdie Sulloway',
#  'Bishop',
#  'Bishop Cattalano',
#  'Bishop Mallinson',
#  'Bitsy Rabler',
#  'Blake',
#  'Blake Murphy',
#  'Blake Peters',
#  'Blanche',
#  'Bluebell Agency Executive',
#  'Bo',
#  'Board Member #1',
#  'Board Member #2',
#  'Bob',
#  'Bob Barnes',
#  'Bob Clinton',
#  'Bob Contino',
#  'Bob Hencamp',
#  'Bob Petri',
#  'Bobby',
#  'Bobby Cruise',
#  "Bobby D'Amico",
#  'Bobby Douglas',
#  'Bobby Jackson',
#  'Bobby Johnson',
#  'Bobby Masconi',
#  'Bobby Navarro',
#  'Bobby Trapido',
#  'Bodega Clerk',
#  'Bodega Owner',
#  'Bomb Squad Detective',
#  'Bomb Squad Officer',
#  'Bonnie Vernon',
#  'Book Seller',
#  'Bouncer',
#  'Boy',
#  'Boy #1',
#  'Boy #2',
#  'Boy #2 / Emmitt',
#  'Boy #3',
#  'Boy in Hall',
#  'Boyd Hartwell',
#  'Brad',
#  'Brad Fletcher',
#  'Brad Hayes',
#  'Brad Hicks',
#  'Brad Kinjo',
#  'Brad Weber',
#  "Brad Weber's Lawyer",
#  'Braden Doucey',
#  'Braden Leddy',
#  'Bradley',
#  'Brady Harrison',
#  'Brandi',
#  "Brandon O'Keefe",
#  'Brannon Lee Redding',
#  'Brass',
#  'Bree Mazelon',
#  'Breena / Nam',
#  'Bremmer',
#  'Brenda',
#  'Brenda Fairchild',
#  'Brenda Nix',
#  'Brendan Cahill',
#  'Brendan Krug',
#  'Brendan Walsh',
#  "Brendan's Birth Mother",
#  'Brent',
#  'Brent Allen Banks',
#  'Brent Latimer',
#  'Brent Williams',
#  'Bret Kim',
#  'Brett Erickson',
#  'Brett Forrester',
#  'Brett Landau',
#  'Brett Smith',
#  'Brett Trask',
#  'Brian',
#  'Brian Ackerman',
#  'Brian Cassidy',
#  'Brian Coyle',
#  'Brian Dancy',
#  'Brian Denker',
#  'Brian Mackey',
#  "Brian O'Malley",
#  'Brian Townsend',
#  'Brian Traymor',
#  'Brianna',
#  'Brickett, David',
#  'Bridget',
#  'Brie',
#  'Briggs',
#  'Brit Yardley',
#  "Brit's Mom",
#  'Britney Dunlap',
#  'Britney Taylor',
#  "Brittany O'Malley",
#  'Brody Clark',
#  'Bronwyn Freed',
#  'Bronwyn Wilkins',
#  'Bronx ADA Winn',
#  'Brook Thornburg',
#  'Brooke Allen',
#  'Brooke Groves Norwalk',
#  'Brooke Groves Norwalk  Groves',
#  'Brooke Robertson',
#  'Brooks Harmon',
#  'Broussard',
#  'Brownstone Man',
#  'Bruce',
#  'Bruce Abbott',
#  'Bruce Clarkson',
#  'Bruce Corbett',
#  'Bruce Derricks',
#  'Bruce Fowler',
#  'Bruce Horton',
#  "Bruce's Lawyer",
#  'Brunette',
#  'Bruno Ozuna',
#  'Bryant Davis',
#  'Bryce Kelton',
#  'Buck',
#  'Bucky Dinucci',
#  'Bud Gabler',
#  'Bud Yellin',
#  'Buddy',
#  'Buddy Greyland',
#  'Building Manager',
#  'Building Super',
#  'Building Superintendent',
#  'Bull Dozer',
#  'Bullhorn Guy',
#  'Bunny Jones',
#  'Bureau Chief Elizabeth Donnelly',
#  'Bureau Chief Paula Foster',
#  'Burglary Detective',
#  'Bursar',
#  'Burt Ferris',
#  'Bus Depot Traveler',
#  'Bus Driver',
#  'Bus Driver #1',
#  'Bus Driver #2',
#  'Bus Passenger',
#  'Bushwick Rape Victim',
#  'Businessman',
#  'Businesswoman',
#  'Buster Flynn',
#  'Butch',
#  'Butcher',
#  'Buxom Assistant',
#  'Byron Marks',
#  'Bystander',
#  'Bystander in Train Station',
#  'C.C. Detective Ben Suarato',
#  'C.O. #1',
#  'C.O. #2',
#  'C.O. #3',
#  'C.O. Albert Martinez',
#  'C.O. Edwards',
#  'C.O. Jerez',
#  'C.O. Leslie',
#  'C.O. McCoy',
#  'C.S.U. Tech',
#  'CCS Officer',
#  'CCU Investigator',
#  'CDC Technician',
#  'CERT Officer',
#  'CIA Officer Chase',
#  'CO #1',
#  'CO Alan Newman',
#  'CO Dalton',
#  'CO Foster',
#  'CO Jerez',
#  'CO Stella Lopez',
#  'CPA Schreiber',
#  'CSI',
#  'CSI Agent',
#  'CSU',
#  'CSU Adrian Sung',
#  'CSU Captain Judith Siper',
#  'CSU Clifton Montgomery',
#  'CSU Detective',
#  'CSU Investigator',
#  'CSU Photographer',
#  'CSU Tech',
#  'CSU Tech #1',
#  'CSU Tech Brice',
#  'CSU Tech Dale Stuckey',
#  'CSU Tech Foster',
#  'CSU Tech GeorgieCSU Technician Georgie',
#  'CSU Tech Harry',
#  'CSU Tech Keegan Timmons',
#  'CSU Tech Layton',
#  'CSU Tech Martin',
#  'CSU Tech Millie Vizcarrondo',
#  'CSU Tech Pat Fisher',
#  'CSU Tech Ramone Vargas',
#  'CSU Tech Supervisor',
#  'CSU TechCSU Technician Georgie',
#  'CSU Technician',
#  'CSU Technician #2',
#  'CSU Technician Burt Trevor',
#  'CSU Technician Georgie',
#  'CSU photographer',
#  'Cabbie',
#  "Cabot's Junior ADA",
#  'Cadet',
#  'Cafe Customer',
#  'Caitlin',
#  'Caitlin La Marque',
#  'Caitlyn Ryan',
#  'Cake Girl',
#  'Cal Cutler',
#  'Cal Oman',
#  'Caleb',
#  'Caleb Breville',
#  'Caleb Bryant',
#  'Caleb Pierce',
#  'Callie Lydell',
#  'Callum Donovan',
#  'Calvin Arliss',
#  'Calvin Jones',
#  'Calvin Portney',
#  'Cambodian Victim',
#  'Camera Guy',
#  'Cameraman',
#  'Cameron Shaw',
#  'Cameron Tyler',
#  'Camille Marino',
#  'Camille Walters',
#  'Campus Cop',
#  'Campus Security Guard',
#  'Campus Security Officer Anthony Schlasser',
#  'Canadian Judge',
#  'Canasta Player',
#  'Candace',
#  'Candace Lamerly',
#  'Candace Shepherd',
#  'Candace Tanner',
#  'Candy',
#  'Candy Forrester',
#  'Cantwell FBI agent',
#  'Captain Barbara Pierce',
#  'Captain Beth Williams',
#  'Captain Charles Lee',
#  'Captain Gerbic',
#  'Captain Jason Harris',
#  'Captain Julia Millfield',
#  'Captain Lloral',
#  'Captain Logan Carter',
#  "Captain Mike O'Brian",
#  'Captain Molloy',
#  'Captain Reece',
#  'Captain Sam Reynolds',
#  'Captain Steven Harris',
#  'Captain Toni Howard',
#  'Cara Gutierrez',
#  'Cara Raleigh',
#  'Carey Thorne',
#  'Carin Healy',
#  'Carissa Gibson',
#  'Carl',
#  'Carl Buchman',
#  'Carl Cooper',
#  'Carl Fleming',
#  'Carl Sawyer',
#  'Carl Vasko  Vucelik',
#  'Carla Gannon',
#  'Carla Sexton',
#  'Carla Vincent',
#  'Carleen Jenkins',
#  'Carlene Ballentine',
#  'Carlo Parisi',
#  "Carlos 'O.G.' Hernandez",
#  'Carlos Guzman',
#  'Carlos Martinez',
#  'Carlos Medina',
#  'Carlos Riva',
#  'Carlotta',
#  'Carly Holbart ',
#  'Carly Hunter',
#  'Carly Rydell',
#  'Carmanuce Cascone',
#  'Carmen',
#  'Carmen Silva',
#  'Carmen Vasquez',
#  'Carol',
#  'Carol Daley',
#  'Carol Lucero',
#  'Carol McEwan',
#  'Carol Porter',
#  'Carol Rogers',
#  'Carole Pinto',
#  'Carole Simms',
#  'Caroline Pereira',
#  'Carolyn Forbes',
#  'Carolyn Maddox',
#  'Carolyn Rivers',
#  'Carolyn Spencer',
#  'Carpenter',
#  'Carrie',
#  'Carrie Huitt',
#  'Carrie Jones',
#  'Carrie Lynn Eldridge',
#  'Carter Pressman',
#  'Case File Dead Victim',
#  'Caseworker Hecht',
#  'Casey',
#  'Casey Novak',
#  'Cash Lewis',
#  'Casino Security',
#  'Cass Magnall',
#  'Cassandra Davina',
#  'Cassandra Sullivan',
#  'Cassidy Cornell  Braidwell',
#  "Cassidy's Lawyer",
#  'Cassie',
#  'Cassie Germaine',
#  'Cassie Muir',
#  'Cat',
#  'Catalina Diaz',
#  'Catalina Soren',
#  'Cate Avery',
#  'Catherine Harrison',
#  'Catherine Summers',
#  'Catholic High School Girl',
#  'Catholic School Girl',
#  "Catignano's Restaurant Manager",
#  'Cece Thornhill',
#  'Cecelia Cruz',
#  'Cecile Dunlap',
#  'Cecilia Santiago',
#  'Cecilia Strayer',
#  'Cedric Jones',
#  'Celia Barber',
#  'Celina Rindell',
#  'Celine',
#  'Cell Man',
#  'Cell Technician',
#  'Center Director',
#  'Cert Officer',
#  'Cesar',
#  'Cesaria Amaro',
#  'Chad',
#  'Chad Miller',
#  'Chad Ogilvy',
#  'Chad Smith',
#  'Chain Gang Inmate #3',
#  'Channel 8 News Anchor',
#  'Chantal Jackson',
#  'Chantel Shepard',
#  'Charisse McCabe',
#  'Charlene',
#  'Charles',
#  'Charles Barrow',
#  'Charles Caulfield',
#  'Charles Eno',
#  'Charles Franklin',
#  'Charles Guzek',
#  'Charles Murphy',
#  'Charles Southerland',
#  'Charley Landry',
#  'Charlie',
#  'Charlie Baker',
#  'Charlie Dobkins',
#  'Charlie Donato',
#  'Charlie Dorsey',
#  'Charlie Horner',
#  'Charlie Monaghan',
#  'Charlie Moss',
#  'Charlie Phillips',
#  'Charlie Ping',
#  'Charlie Poe',
#  'Charlotte',
#  'Charlotte Cooke',
#  'Charlotte Jones',
#  'Charlotte Owens',
#  'Charlotte Truex',
#  'Charmaine Briggs',
#  'Chauffer',
#  'Chauncey Zeirko',
#  'Chaz',
#  'Cheerleader',
#  'Chelsea Arndale',
#  'Chelsea Market Shopper',
#  'Chelsea Summers-Maddox',
#  'Chemist Lockhart',
#  'Chen Wu',
#  'Cherry Gabardelli',
#  'Cheryl',
#  'Cheryl Avery',
#  'Cheryl Davenport',
#  'Cheryl McCrae',
#  'Chester Hadler',
#  'Chester Jansen',
#  'Chester Lake',
#  'Chet',
#  'Chez Jolene Customer',
#  'Chick',
#  'Chief Butcher',
#  'Chief Charles Patton',
#  'Chief Dodds Aide',
#  'Chief Duggan',
#  'Chief Ed James',
#  'Chief Gabriel',
#  'Chief Sullivan',
#  'Chief of Detectives',
#  'Chief of Detectives Muldrew',
#  'Child',
#  'Child Services Rep',
#  'Child Visting Jail',
#  'Chinese American Officer',
#  'Chinese Thug',
#  'Chloe',
#  'Chloe Dutton',
#  'Chloe Fuller',
#  'Chloe Harrington',
#  'Chloe Sellers',
#  ...]

# %%
# Remove actors without roles listed
df_cast.loc[82,'actor'].remove('Keith Reddin')
df_cast.loc[232,'actor'].remove('Robert Turano')
df_cast.loc[241,'actor'].remove('Tamilla Woodard')
df_cast.loc[242,'actor'].remove('Viola Harris')
df_cast.loc[247,'actor'].remove('Cliff Bemis')
df_cast.loc[302,'actor'].remove('Robert Sella')
df_cast.loc[425,'actor'].remove('Callie Thorne')
df_cast.loc[428,'actor'].remove('Richard Kind')

# %%
# Check that the number of actors equals the number of characters in each episode
df_cast['actor_count'] = [len(list) for list in df_cast['actor']]
df_cast['character_count'] = [len(list) for list in df_cast['character']]
df_cast['actor_role_check'] = df_cast['actor_count'] - df_cast['character_count']
df_cast[df_cast['actor_role_check'] != 0].count()
# Out:
# actor               0
# character           0
# episode_name        0
# actor_count         0
# character_count     0
# actor_role_check    0
# dtype: int64

# %% [markdown]
# ### Merge df_episode and df_cast to create df_summary

# %%
# Merge df_episode and df_cast, drop the actor and character columns, drop rows with null values
df_summary = pd.merge(df_episode, df_cast, on='episode_name', how='left')
df_summary = df_summary.dropna()
# df_summary = df_summary.drop(['actor','character'], axis=1)
df_summary.head(1)
# Out:
#   date_published     episode episode_name rating_count  rating_value     season                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       actor  \
# 0 1999-09-20       Episode 1  Payback      511          8.4           Season 1   [Christopher Meloni, Mariska Hargitay, Richard Belzer, Dann Florek, Gordana Rashovich, Dean Winters, Michelle Hurd, Isabel Gillies, Elizabeth Ashley, Ned Eisenberg, Tina Benko, Ronald Guttman, Mark Zimmerman, Angie Harmon, Mili Avital, Leslie Hendrix, P.J. Brown, Ramsey Faragallah, Rebecca Creskoff, Angela Bullock, Mark Nelson, Jeremy Bergman, Matt Skollar, Irma St. Paule, Sevanne Kassarjian, Daniel Bess, Judy Del Giudice, Bill Driscoll, Vivian Nesbitt, Chris Orbach, Jesse Jesus Salazar, Frank Anello, Rohan Quine, Steven Zirnkilton]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               character  actor_count  character_count  actor_role_check
# 0  [Elliot Stabler, Olivia Benson, John Munch, Donald Cragen, Anya Rugova, Brian Cassidy, Monique Jeffries, Kathy Stabler, Serena Benson, Jerry Kleinert, Mrs. Panacek, Gallery Owner, Mr. Dupree, Abbie Carmichael, Marta Stevens, Dr. Elizabeth Rodgers, Bremmer, Taxi Driver, Waitress, Prosecutor, Robert Stevens, Nicholas Stevens, Victor Spicer, Aunt Jashari, Ileana Jashari, Policeman, Judge, Mr. Kloster, Farley, Detective Ken Briscoe, Victim, NYPD Officer, Gallery Owner's assistant, Opening Announcer]  34.0         34.0             0.0

# %%
# Create ep_id, delete columns that are no longer needed
df_summary['episode'] = df_summary['episode'].apply(lambda x: x.replace(' ','_'))
df_summary['episode'] = df_summary['episode'].apply(lambda x: x.replace('_Episode_','0') if len(x)==10 else x.replace('_Episode_',''))
df_summary['season'] = df_summary['season'].apply(lambda x: x.replace(' ','_'))
df_summary['season'] = df_summary['season'].apply(lambda x: x.replace('Season_','0') if len(x)==9 else x.replace('Season_',''))
df_summary['ep_id'] = df_summary.apply(lambda x: '%s%s' % (x['season'], x['episode']), axis=1)
df_summary=df_summary.drop(['season','episode','actor_count','character_count','actor_role_check'], axis=1)
df_summary.head(1)
# Out:
#   date_published episode_name rating_count  rating_value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       actor  \
# 0 1999-09-20      Payback      511          8.4           [Christopher Meloni, Mariska Hargitay, Richard Belzer, Dann Florek, Gordana Rashovich, Dean Winters, Michelle Hurd, Isabel Gillies, Elizabeth Ashley, Ned Eisenberg, Tina Benko, Ronald Guttman, Mark Zimmerman, Angie Harmon, Mili Avital, Leslie Hendrix, P.J. Brown, Ramsey Faragallah, Rebecca Creskoff, Angela Bullock, Mark Nelson, Jeremy Bergman, Matt Skollar, Irma St. Paule, Sevanne Kassarjian, Daniel Bess, Judy Del Giudice, Bill Driscoll, Vivian Nesbitt, Chris Orbach, Jesse Jesus Salazar, Frank Anello, Rohan Quine, Steven Zirnkilton]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               character  ep_id
# 0  [Elliot Stabler, Olivia Benson, John Munch, Donald Cragen, Anya Rugova, Brian Cassidy, Monique Jeffries, Kathy Stabler, Serena Benson, Jerry Kleinert, Mrs. Panacek, Gallery Owner, Mr. Dupree, Abbie Carmichael, Marta Stevens, Dr. Elizabeth Rodgers, Bremmer, Taxi Driver, Waitress, Prosecutor, Robert Stevens, Nicholas Stevens, Victor Spicer, Aunt Jashari, Ileana Jashari, Policeman, Judge, Mr. Kloster, Farley, Detective Ken Briscoe, Victim, NYPD Officer, Gallery Owner's assistant, Opening Announcer]  01_01

# %%
# Convert rating_count into int
df_summary['rating_count'] = df_summary['rating_count'].apply(lambda x: x.replace(',',''))
df_summary['rating_count'] = df_summary['rating_count'].apply(lambda x: int(x))

# %%
df_summary.to_csv('svu_cleaned.csv')
